# %%
# author: Dr. Sandra Isabelle Schmid

# requirements:
# 1) spacy: $ pip install -U spacy
# 2) spacy chinese package: $ python -m spacy download zh_core_web_lg

# for spacy documentation concerning this code see:
# spacy in general: https://spacy.io/usage/spacy-101
# visualization of dependencies and named entities: https://spacy.io/usage/visualizers
# chinese packages for spacy: https://spacy.io/models/zh


# import chinese package
import zh_core_web_lg
# import library for visualizing word relations
from spacy import displacy

# load my nlp (chinese)
nlp = zh_core_web_lg.load()

# %%
# define or load document
# text from xinhuanet.com: http://www.xinhuanet.com/local/2020-08/04/c_1126320957.htm
doc = nlp('《北京市生活垃圾管理条例》正式实施已满3个月。昨天下午，市城市管理委召开新闻发布会，市城管执法局、市民政局、市妇联等部门联合通报新版条例实施3个月来本市垃圾分类开展总体情况、执法情况及社会动员情况。记者了解到，3个月来，全市家庭厨余垃圾分出量增长4倍有余。接下来，本市将在社区广泛开展“盯桶”“守桶”行动，市妇联还将组建7000支、10万人的巾帼志愿者队参与桶前值守。')

# text about pleco fish from baidu: https://baike.baidu.com/item/%E9%B2%B6%E9%B1%BC/1579868
doc = nlp('鲶鱼又名胡子鱼、塘鲺，显著特征是周身无鳞、体表多黏液、头扁口阔、上下颌各有4根条胡须，分布广泛，主要产于长江和珠江流域，仲春至仲夏（4~7月）为最佳食用季节。鲶鱼是肉食性鱼类，其肉质细嫩少刺、美味浓郁，富含蛋白质和脂肪，营养丰富，尤其适宜体质虚弱、营养不良之人食用')

# %%
def visualize_word_relations(document):
    sentence_spans=list(document.sents)
    for x in sentence_spans:
        # displacy.render(x, style="dep", jupyter=True, options={'distance': 130})
        displacy.render(x, style="dep", jupyter=True, options={'distance': 130, "compact": True})
        
def visualize_named_entities(document):
    for x in sentence_spans:
        displacy.render(x, style="ent", jupyter=True, options={'distance': 60, "compact": True})

# %%
visualize_word_relations(doc)
visualize_named_entities(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="f6ec99f47f2541ccb5cd74b2ac578e62-0" class="displacy" width="4470" height="722.0" direction="ltr" style="max-width: none; height: 722.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">鲶鱼</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">又</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="310">名</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="310">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="440">胡子</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="440">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="570">鱼、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">塘鲺，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">显著</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">特征</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">是</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">周身无鳞、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">体表</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">多</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">黏液、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1740">头扁</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1740">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">口阔、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">上下颌</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">各</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2260">有</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2260">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">根</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">条</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">胡须，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">分布</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3040">广泛，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">主要</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3300">产于</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3430">长江</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3560">和</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3560">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">珠江</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3820">流域，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="632.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">仲春</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="c101a8f186c941ff929b57401190cb38-0" class="displacy" width="570" height="267.0" direction="ltr" style="max-width: none; height: 267.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">为</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">最佳</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="310">食用</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="177.0">
#     <tspan class="displacy-word" fill="currentColor" x="440">季节。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="440">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c101a8f186c941ff929b57401190cb38-0-0" stroke-width="2px" d="M62,132.0 62,88.66666666666666 440.0,88.66666666666666 440.0,132.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c101a8f186c941ff929b57401190cb38-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,134.0 L58,126.0 66,126.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c101a8f186c941ff929b57401190cb38-0-1" stroke-width="2px" d="M192,132.0 192,110.33333333333333 307.0,110.33333333333333 307.0,132.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c101a8f186c941ff929b57401190cb38-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M192,134.0 L188,126.0 196,126.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c101a8f186c941ff929b57401190cb38-0-2" stroke-width="2px" d="M322,132.0 322,110.33333333333333 437.0,110.33333333333333 437.0,132.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c101a8f186c941ff929b57401190cb38-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound:nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M322,134.0 L318,126.0 326,126.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="3af1955507094b208cbd3fe1c3e92002-0" class="displacy" width="3300" height="657.0" direction="ltr" style="max-width: none; height: 657.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">鲶鱼</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">是</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="310">肉食性</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="440">鱼类，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="440">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="570">其</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="570">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">肉质</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">细嫩</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">少刺、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">美味</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">浓郁，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">富含</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">蛋白质</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">和</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1740">脂肪，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1740">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">营养</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">丰富，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">尤其</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2260">适宜</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2260">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">体质</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">虚弱、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">营养</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">不良</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">之</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="3040">人</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="567.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">食用</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3af1955507094b208cbd3fe1c3e92002-0-0" stroke-width="2px" d="M62,522.0 62,457.0 425.0,457.0 425.0,522.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3af1955507094b208cbd3fe1c3e92002-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,524.0 L58,516.0 66,516.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3af1955507094b208cbd3fe1c3e92002-0-1" stroke-width="2px" d="M192,522.0 192,478.6666666666667 422.0,478.6666666666667 422.0,522.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3af1955507094b208cbd3fe1c3e92002-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M192,524.0 L188,516.0 196,516.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3af1955507094b208cbd3fe1c3e92002-0-2" stroke-width="2px" d="M322,522.0 322,500.3333333333333 419.0,500.3333333333333 419.0,522.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3af1955507
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">鲶鱼又名胡子鱼、塘鲺，显著特征是
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     周身无鳞
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 、体表多黏液、头扁口阔、上下颌各有
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# 根条胡须，分布广泛，主要产于
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     长江
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# 和
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     珠江
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# 流域，
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     仲春至仲夏
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# （4~7月）</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">为最佳食用季节。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">鲶鱼是肉食性鱼类，其肉质细嫩少刺、美味浓郁，富含蛋白质和脂肪，营养丰富，尤其适宜体质虚弱、营养不良之人食用</div></span>

# %%
# extract information of a document:

# print all named entities together with its kind (location, date, person...) contained in the text "doc"
for ent in doc.ents:
      #print(ent.text, ent.label_)
      # nicer formatted
      print(f"{ent.text:<15}{ent.label_:<10}")

# for every sentence in the document, print the respective sentence
for s in doc.sents:
  print(s)

# for every token in the document, print the token, its word species and its grammatical role in the sentence
for token in doc:
  print(token.text, token.pos_, token.dep_)
# Out:
# 周身无鳞           PERSON
# 4              CARDINAL
# 长江             LOC
# 珠江             LOC
# 仲春至仲夏          DATE
# 鲶鱼又名胡子鱼、塘鲺，显著特征是周身无鳞、体表多黏液、头扁口阔、上下颌各有4根条胡须，分布广泛，主要产于长江和珠江流域，仲春至仲夏（4~7月）
# 为最佳食用季节。
# 鲶鱼是肉食性鱼类，其肉质细嫩少刺、美味浓郁，富含蛋白质和脂肪，营养丰富，尤其适宜体质虚弱、营养不良之人食用
# 鲶鱼 NOUN nsubj
# 又 ADV advmod
# 名 NUM ROOT
# 胡子 NOUN compound:nn
# 鱼 NOUN conj
# 、 PUNCT punct
# 塘鲺 NOUN dobj
# ， PUNCT punct
# 显著 ADJ amod
# 特征 NOUN conj
# 是 VERB cop
# 周身无鳞 PROPN dep
# 、 PUNCT punct
# 体表 NOUN nsubj
# 多 VERB dep
# 黏液 NOUN conj
# 、 PUNCT punct
# 头扁 VERB compound:nn
# 口阔 NOUN conj
# 、 PUNCT punct
# 上下颌 NOUN nsubj
# 各 ADV advmod
# 有 VERB conj
# 4 NUM nummod
# 根 NUM mark:clf
# 条 NUM amod
# 胡须 NOUN dobj
# ， PUNCT punct
# 分布 NOUN nsubj
# 广泛 VERB conj
# ， PUNCT punct
# 主要 ADV advmod
# 产于 VERB conj
# 长江 PROPN conj
# 和 CCONJ cc
# 珠江 PROPN nmod:assmod
# 流域 NOUN dobj
# ， PUNCT punct
# 仲春 NOUN conj
# 至 CCONJ cc
# 仲夏 NOUN conj
# （ PUNCT punct
# 4~7月 NOUN parataxis:prnmod
# ） PUNCT punct
# 为 ADP cop
# 最佳 ADJ amod
# 食用 NOUN compound:nn
# 季节 NOUN ROOT
# 。 PUNCT punct
# 鲶鱼 NOUN nsubj
# 是 VERB cop
# 肉食性 NOUN compound:nn
# 鱼类 NOUN ROOT
# ， PUNCT punct
# 其 PRON nmod:poss
# 肉质 NOUN nsubj
# 细嫩 VERB amod
# 少刺 NOUN conj
# 、 PUNCT punct
# 美味 NOUN nsubj
# 浓郁 VERB conj
# ， PUNCT punct
# 富含 VERB conj
# 蛋白质 NOUN conj
# 和 CCONJ cc
# 脂肪 NOUN dobj
# ， PUNCT punct
# 营养 NOUN nsubj
# 丰富 VERB conj
# ， PUNCT punct
# 尤其 ADV advmod
# 适宜 VERB amod
# 体质 NOUN nsubj
# 虚弱 VERB acl
# 、 PUNCT punct
# 营养 NOUN nsubj
# 不良 VERB conj
# 之 PART mark
# 人 NOUN nsubj
# 食用 VERB conj
